# %% [markdown]
# #Theory Questions
#
# ##1. What is Hypothesis Testing in Statistics?
#
# Hypothesis testing is a statistical method used to make decisions or inferences about population parameters based on a sample of data.
#
# ### ✅ Key Terms:
# - **Null Hypothesis (H₀):** A general statement or default position that there is no effect or no difference.
# - **Alternative Hypothesis (H₁ or Ha):** A statement that contradicts the null hypothesis.
#
# ### 🎯 Purpose:
# To determine whether the observed data provides enough evidence to reject the null hypothesis.
#
# ### 📊 Common Tests:
# - **Z-test** (when population variance is known)
# - **T-test** (small sample sizes, unknown variance)
# - **Chi-square test** (for categorical data)
# - **ANOVA** (compare more than two means)
#
# ### 🔍 Steps in Hypothesis Testing:
# 1. Formulate H₀ and H₁
# 2. Choose significance level (α), typically 0.05
# 3. Select the appropriate test
# 4. Compute test statistic
# 5. Compare with critical value or p-value
# 6. Make a decision (Reject or Fail to Reject H₀)
#
# ### 📌 Example:
# Testing whether a sample mean is significantly different from a known population mean.
#
# ---
# ##2.  What is the null hypothesis, and how does it differ from the alternative hypothesis ?
#
# In hypothesis testing, we use two competing statements to evaluate a claim:
#
# ### 📌 Null Hypothesis (H₀):
# - A statement of **no effect**, **no difference**, or **status quo**.
# - It assumes that any kind of difference or significance you see in your data is due to chance.
# - We **test** this assumption with the data.
#
# **Example:**
# H₀: The average test score of students is 75.
#
# ---
#
# ### ⚡ Alternative Hypothesis (H₁ or Ha):
# - A statement that **contradicts the null hypothesis**.
# - It suggests that there **is** an effect or a difference.
# - If evidence from the data is strong enough, we **reject H₀ in favor of H₁**.
#
# **Example:**
# H₁: The average test score of students is **not** 75.
#
# ---
#
# ### 🎯 Summary Table:
#
# | Feature                 | Null Hypothesis (H₀)       | Alternative Hypothesis (H₁)  |
# |------------------------|----------------------------|------------------------------|
# | Assumes                | No change or effect        | There is a change or effect  |
# | Decision Based On      | p-value & significance     | Rejection of H₀              |
# | Goal                   | To test its validity       | To find evidence against H₀  |
#
# ---
# ##3.  What is the significance level in hypothesis testing, and why is it important ?
#
#
# ### 📌 Definition:
# The **significance level**, denoted by **α (alpha)**, is the **probability of rejecting the null hypothesis (H₀) when it is actually true**.
#
# In simpler terms, it's the **threshold for how much risk we're willing to take** of making a **Type I error** (false positive).
#
# ---
#
# ### ✅ Common Significance Levels:
# - **α = 0.05** → 5% risk of wrongly rejecting H₀
# - **α = 0.01** → 1% risk (more strict)
# - **α = 0.10** → 10% risk (less strict)
#
# ---
#
# ### 🧪 Why is it Important?
#
# - Sets the **critical boundary** for decision-making.
# - Helps control the risk of **incorrect conclusions**.
# - Balances **sensitivity** (detecting real effects) with **specificity** (avoiding false positives).
#
# ---
#
# ### 📊 Example:
# If p-value < α → **Reject H₀**
# If p-value ≥ α → **Fail to reject H₀**
#
# Choosing a lower α makes the test **more conservative** (harder to reject H₀), while a higher α increases the **chance of finding significance** but also the risk of error.
#
# ---
# ##4.  What does a P-value represent in hypothesis testing ?
#
# ## 🔍 What Does a P-value Represent in Hypothesis Testing?
#
# ### 📌 Definition:
# The **P-value** (probability value) is the **likelihood of observing the sample data, or something more extreme, assuming the null hypothesis (H₀) is true**.
#
# ---
#
# ### 🎯 Interpretation:
#
# - A **small p-value** (typically ≤ 0.05) suggests **strong evidence against** the null hypothesis.
# - A **large p-value** (> 0.05) suggests **weak evidence** against the null hypothesis → we **fail to reject** it.
#
# ---
#
# ### 🚦 Decision Rule:
#
# | P-value           | Conclusion                        |
# |------------------|------------------------------------|
# | p ≤ α (e.g., 0.05) | Reject the null hypothesis (H₀)   |
# | p > α            | Fail to reject the null hypothesis |
#
# ---
#
# ### 📌 Example:
# If a test returns a **p-value of 0.03**, and you’re using a **significance level of 0.05**, you reject the null hypothesis because 0.03 < 0.05.
#
# This means the observed data would be **very unlikely** under the assumption that H₀ is true.
#
# ---
# ##5.  How do you interpret the P-value in hypothesis testing ?
#
#
# ### 🧪 P-value Interpretation:
#
# The **p-value** tells us the probability of obtaining a result **as extreme as the observed one**, assuming the **null hypothesis (H₀)** is true.
#
# ---
#
# ### 🚦 Interpretation Rules:
#
# | P-value           | Interpretation                                      | Action                      |
# |------------------|-----------------------------------------------------|-----------------------------|
# | **p ≤ 0.01**      | Very strong evidence against H₀                    | Reject H₀                  |
# | **0.01 < p ≤ 0.05**| Moderate evidence against H₀                      | Reject H₀                  |
# | **0.05 < p ≤ 0.10**| Weak evidence against H₀                          | Often fail to reject H₀    |
# | **p > 0.10**      | No evidence against H₀                            | Fail to reject H₀          |
#
# ---
#
# ### ✅ Example Statement:
# - If **p = 0.03**, and **α = 0.05**, we say:
#   > "Since the p-value is less than 0.05, we reject the null hypothesis. There is statistically significant evidence to support the alternative hypothesis."
#
# ---
#
# ### ⚠️ Important Note:
# A **low p-value does not prove the alternative hypothesis is true**—it only suggests that the observed data is unlikely under the null hypothesis.
#
# ---
# ##6.  What are Type 1 and Type 2 errors in hypothesis testing ?
#
# In hypothesis testing, we make a decision to **reject** or **fail to reject** the null hypothesis (H₀).
# Sometimes, our decision can be wrong. These wrong decisions are called **errors**.
#
# ---
#
# ### ❗ Type I Error (False Positive)
# - Occurs when we **reject the null hypothesis** even though it's **actually true**.
# - It's a **false alarm**.
# - The probability of making a Type I error is the **significance level (α)**, usually 0.05.
#
# 🧠 Think: We said something is significant, but it's not.
#
# ---
#
# ### ❓ Type II Error (False Negative)
# - Occurs when we **fail to reject the null hypothesis** even though it's **actually false**.
# - We **miss a real effect**.
# - The probability of making a Type II error is denoted by **β**.
# - Power of a test = **1 - β** (chance of correctly rejecting H₀)
#
# 🧠 Think: We missed something that was actually there.
#
# ---
#
# ### 📊 Error Decision Table:
#
# |                    | **H₀ True**           | **H₀ False**           |
# |--------------------|-----------------------|------------------------|
# | **Reject H₀**      | ❗ Type I Error        | ✅ Correct Decision     |
# | **Fail to Reject H₀** | ✅ Correct Decision     | ❓ Type II Error        |
#
# ---
#
# ### 🎯 Goal:
# - Minimize **both** errors, but reducing one often increases the other.
# - Select a **significance level (α)** and ensure **enough sample size** to reduce both risks.
#
# ---
# ##7. ## 🎯 What is the Difference Between a One-Tailed and a Two-Tailed Test in Hypothesis Testing?
#
# In hypothesis testing, the **direction** of the test depends on the **research question** and how the **alternative hypothesis (H₁)** is formulated.
#
# ---
#
# ### ➤ One-Tailed Test (Directional)
# - Tests for a change in **one direction only** (either greater than or less than).
# - More **powerful** in detecting an effect in that one direction.
# - Used when we have a specific directional hypothesis.
#
# **Example:**
# - H₀: μ = 75
# - H₁: μ > 75 → Right-tailed test
# - H₁: μ < 75 → Left-tailed test
#
# ---
#
# ### ➤ Two-Tailed Test (Non-Directional)
# - Tests for any **significant difference**, regardless of direction.
# - Splits the significance level (α) between **both tails** of the distribution.
# - Used when we are only interested in **any difference**, not direction.
#
# **Example:**
# - H₀: μ = 75
# - H₁: μ ≠ 75 → Two-tailed test
#
# ---
#
# ### 🧠 Summary Table:
#
# | Test Type       | Alternative Hypothesis | Critical Region        | Use When                      |
# |-----------------|------------------------|------------------------|-------------------------------|
# | One-Tailed      | H₁: μ > μ₀ or μ < μ₀   | One side of distribution | Direction of effect matters   |
# | Two-Tailed      | H₁: μ ≠ μ₀             | Both sides              | Any difference matters        |
#
# ---
# ##8. ## 🧮 What is the Z-test, and When is it Used in Hypothesis Testing?
#
# ### 📌 What is a Z-test?
#
# A **Z-test** is a statistical test used to determine whether there is a significant difference between the **sample mean** and the **population mean**, or between two sample means, **when the population standard deviation is known**.
#
# ---
#
# ### 📊 Formula for One-Sample Z-test:
#
# $$
# Z = \frac{\bar{x} - \mu}{\sigma / \sqrt{n}}
# $$
#
# Where:
# - \( \bar{x} \) = Sample mean
# - \( \mu \) = Population mean
# - \( \sigma \) = Population standard deviation
# - \( n \) = Sample size
#
# ---
#
# ### ✅ When to Use a Z-test?
#
# | Condition                          | Use Z-test? |
# |-----------------------------------|-------------|
# | Population standard deviation known | ✅ Yes       |
# | Large sample size (n ≥ 30)          | ✅ Preferred |
# | Normal distribution assumed         | ✅ Yes       |
#
# ---
#
# ### 🔍 Types of Z-tests:
# - **One-sample Z-test**: Compare sample mean to population mean.
# - **Two-sample Z-test**: Compare means from two independent samples.
# - **Z-test for proportions**: Compare proportions (e.g., % support in elections).
#
# ---
#
# ### 📌 Note:
# If the population standard deviation is **unknown**, or the sample size is **small (n < 30)**, use a **T-test** instead.
#
# ---
#
# ##9. ## 📏 How Do You Calculate the Z-score, and What Does It Represent in Hypothesis Testing?
#
# ### 📌 What is a Z-score?
#
# A **Z-score** (or standard score) tells you **how many standard deviations** a data point or sample mean is from the population mean.
#
# ---
#
# ### 🧮 Formula for Z-score (One-Sample Z-test):
#
# $$
# Z = \frac{\bar{x} - \mu}{\sigma / \sqrt{n}}
# $$
#
# Where:
# - \( \bar{x} \): Sample mean
# - \( \mu \): Population mean
# - \( \sigma \): Population standard deviation (known)
# - \( n \): Sample size
#
# ---
#
# ### 🎯 What Does the Z-score Represent?
#
# - The **distance** (in standard deviations) between the sample statistic and the population parameter.
# - A **high absolute Z-score** (e.g., > 1.96 for α = 0.05 in a two-tailed test) means the sample is **unlikely under the null hypothesis**.
# - It helps us determine the **p-value** and whether to **reject the null hypothesis**.
#
# ---
#
# ### 🔢 Example Interpretation:
#
# - **Z = 0** → Sample mean exactly equals population mean
# - **Z = 2** → Sample mean is 2 standard errors above the population mean
# - **Z = -2** → Sample mean is 2 standard errors below the population mean
#
# ---
#
# ### 🚨 Decision Rule (Two-Tailed Test):
# - If |Z| > 1.96 → **Reject H₀** at 5% significance level
# - Otherwise → **Fail to reject H₀**
#
# ---
# ##10. ## 📉 What is the T-distribution, and When Should It Be Used Instead of the Normal Distribution?
#
# ### 📌 What is the T-distribution?
#
# The **T-distribution** (also called **Student's t-distribution**) is a probability distribution used in statistics to estimate population parameters **when the sample size is small** and/or the **population standard deviation is unknown**.
#
# ---
#
# ### 🧮 Formula (One-sample T-test):
#
# $$
# t = frac{bar{x} - \mu}{s / \sqrt{n}}
# $$
#
# **Where:**
#
# - $\bar{x}$ = Sample mean
# - $\mu$ = Population mean
# - $s$ = Sample standard deviation
# - $n$ = Sample size
# ---
#
# ### 🆚 T-distribution vs Normal Distribution:
#
# | Feature                      | T-distribution         | Normal distribution     |
# |-----------------------------|------------------------|--------------------------|
# | Used when                   | σ unknown, n small     | σ known, n large (n ≥ 30)|
# | Shape                       | Flatter, heavier tails | Bell-shaped
#
# ##11. ## ⚖️ What is the Difference Between a Z-test and a T-test?
#
# Both **Z-test** and **T-test** are statistical methods used to test hypotheses about population means. The key differences lie in the sample size and whether the population standard deviation is known.
#
# ---
#
# ### 🔍 Key Differences:
#
# | Feature                          | **Z-test**                                | **T-test**                                |
# |----------------------------------|--------------------------------------------|--------------------------------------------|
# | Use Case                         | Large samples (n ≥ 30)                     | Small samples (n < 30)                     |
# | Population Standard Deviation    | Known (σ is known)                        | Unknown (σ is estimated using sample)     |
# | Distribution Used                | Standard Normal (Z-distribution)          | T-distribution                            |
# | Shape of Distribution            | Fixed (bell curve)                        | Flatter tails (changes with degrees of freedom) |
# | More Reliable When               | Variability is known and sample is large  | Variability is unknown and sample is small |
#
# ---
#
# ### ✅ When to Use Which?
#
# - Use a **Z-test** when:
#   - The population standard deviation is **known**
#   - The sample size is **large (n ≥ 30)**
#
# - Use a **T-test** when:
#   - The population standard deviation is **unknown**
#   - The sample size is **small (n < 30)**
#
# ---
#
# ### 📌 Tip:
# As sample size increases, the **T-distribution approaches the Z-distribution**.
#
# ##12. What is the T-test, and How is it Used in Hypothesis Testing?
#
# ### 📌 What is a T-test?
#
# A **T-test** is a statistical method used to determine if there is a **significant difference between the means** of one or two groups.
#
# It is used when:
# - The sample size is **small (n < 30)**
# - The **population standard deviation is unknown**
# - The data is approximately **normally distributed**
#
# ---
#
# ### 🎯 Types of T-tests:
#
# | Test Type          | Use Case                                              |
# |--------------------|--------------------------------------------------------|
# | **One-sample T-test** | Compare sample mean to a known population mean        |
# | **Two-sample T-test** | Compare means of two independent groups               |
# | **Paired T-test**     | Compare means of the same group at two time points    |
#
# ---
#
# ### 🧮 Formula (One-sample T-test):
#
# \[
# t = \frac{\bar{x} - \mu}{s / \sqrt{n}}
# \]
#
# Where:
# - \( \bar{x} \): Sample mean
# - \( \mu \): Population mean
# - \( s \): Sample standard deviation
# - \( n \): Sample size
#
# ---
#
# ### ✅ Steps to Use a T-test in Hypothesis Testing:
#
# 1. Define null hypothesis (H₀) and alternative hypothesis (H₁)
# 2. Choose significance level (α), commonly 0.05
# 3. Calculate the T-statistic
# 4. Determine the p-value from the T-distribution
# 5. Compare the p-value with α:
#    - If **p-value < α** → Reject H₀
#    - If **p-value ≥ α** → Fail to reject H₀
#
# ---
#
# ### 📌 Example Use:
# Test if the average test score of a sample is different from the expected population mean.
#
# ---
# ##13. What is the Relationship Between Z-test and T-test in Hypothesis Testing?
#
# The **Z-test** and **T-test** are closely related statistical methods used to test hypotheses about population means.
#
# ---
#
# ### 🧪 Similarities:
#
# - Both are used to compare **sample means** against a **population mean** or between two groups.
# - Both assume that the data is **normally distributed**.
# - Both compute a **test statistic** (Z or t) to assess significance.
# - Both compare a test statistic to a critical value or compute a **p-value**.
#
# ---
#
# ### ⚖️ Key Differences:
#
# | Feature                      | Z-test                             | T-test                              |
# |-----------------------------|-------------------------------------|--------------------------------------|
# | Use Case                    | Known population std dev (σ)       | Unknown population std dev           |
# | Sample Size                 | Typically n ≥ 30                   | Typically n < 30                     |
# | Distribution Used           | Z (standard normal)                | t-distribution                       |
# | Shape of Distribution       | Fixed bell curve                   | Flatter with heavier tails (depends on degrees of freedom) |
# | Becomes similar to Z-test   | N/A                                | As n inc
#
# ##14. What is a Confidence Interval, and How is it Used to Interpret Statistical Results?
#
# ### 📌 What is a Confidence Interval?
#
# A **confidence interval (CI)** is a range of values, derived from a sample, that is likely to contain the **true population parameter** (like the mean) with a certain level of confidence.
#
# ---
#
# ### 🧮 Confidence Interval Formula (for mean):
#
# If the population standard deviation is **unknown**, we use the **T-distribution**:
#
# $$
# \text{CI} = \bar{x} \pm t_{\alpha/2} \cdot \left(\frac{s}{\sqrt{n}}\right)
# $$
#
# Where:
# - \( \bar{x} \): Sample mean
# - \( s \): Sample standard deviation
# - \( n \): Sample size
# - \( t_{\alpha/2} \): t-critical value from t-distribution (based on confidence level and degrees of freedom)
#
# ---
#
# ### 🎯 Interpreting a 95% Confidence Interval:
#
# > "We are 95% confident that the **true population mean** lies within this interval."
#
# This **does not** mean there's a 95% chance that the population mean lies in the interval. Instead, it means **95% of such intervals** would contain the true mean if we repeated the sampling many times.
#
# ---
#
# ### ✅ Example:
#
# If the 95% confidence interval for average test scores is:
#
# $$
# [70.2, 73.8]
# $$
#
# We say:
# > "We are 95% confident that the average score of the population is between 70.2 and 73.8."
#
# ##15.  What is the margin of error, and how does it affect the confidence interval ?
#
# ### 📌 What is the Margin of Error?
#
# The **margin of error (MoE)** is the amount added and subtracted from the sample statistic (e.g., mean or proportion) to create a **confidence interval**. It represents the **maximum expected difference** between the sample estimate and the true population parameter.
#
# ---
#
# ### 🧮 Formula (for mean, unknown σ):
#
# \[
# \text{Margin of Error (MoE)} = t_{\alpha/2} \cdot \left(\frac{s}{\sqrt{n}}\right)
# \]
#
# Where:
# - \( t_{\alpha/2} \): t-critical value from t-distribution
# - \( s \): Sample standard deviation
# - \( n \): Sample size
#
# ---
#
# ### 🎯 How It Affects the Confidence Interval:
#
# \[
# \text{Confidence Interval} = \bar{x} \pm \text{Margin of Error}
# \]
#
# - **Larger MoE → wider confidence interval** → more uncertainty
# - **Smaller MoE → narrower confidence interval** → more precision
#
# ---
#
# ### 📌 Factors that Increase Margin of Error:
# - Smaller sample size
# - Higher confidence level (e.g., 99% vs 95%)
# - More variability in the data (higher standard deviation)
#
# ---
#
# ### ✅ Summary:
#
# - The **margin of error controls the width** of the confidence interval.
# - It tells us how much the sample estimate might differ from the actual population value.
#
# ##16.  How is Bayes' Theorem used in statistics, and what is its significance ?
#
# ### 📌 What is Bayes' Theorem?
#
# **Bayes' Theorem** is a mathematical formula used to update the **probability of a hypothesis** based on new evidence.
#
# ---
#
# ### 🧮 Bayes’ Theorem Formula:
#
# $$
# P(A|B) = \frac{P(B|A) \cdot P(A)}{P(B)}
# $$
#
# Where:
# - \( P(A|B) \): Posterior probability (probability of A given B)
# - \( P(B|A) \): Likelihood (probability of B given A)
# - \( P(A) \): Prior probability of A
# - \( P(B) \): Total probability of B
#
# ---
#
# ### 🎯 How Is It Used?
#
# Bayes' Theorem allows us to:
# - **Update probabilities** when new information is available.
# - Make **informed decisions** in fields like medical diagnosis, spam filtering, and machine learning.
# - Incorporate **prior knowledge** into statistical inference.
#
# ---
#
# ### 📌 Example Use Cases:
# - **Medical Testing**: Update the probability that a patient has a disease given a positive test result.
# - **Email Filtering**: Update the probability that an email is spam based on keywords.
# - **Machine Learning**: Used in **Naive Bayes classifiers**.
#
# ---
#
# ### ✅ Significance in Statistics:
#
# - Helps move from **prior beliefs** to **posterior probabilities**.
# - Core of **Bayesian inference**, an alternative to classical frequentist methods.
# - Useful when data is limited but prior knowledge is available.
#
# ##17.What is the Chi-square Distribution, and When Is It Used?
#
# ### 📌 What is the Chi-square (χ²) Distribution?
#
# The **Chi-square distribution** is a **skewed, non-negative** distribution that arises when summing the squares of independent standard normal variables.
#
# It is widely used in **inferential statistics**, especially for **categorical data**.
#
# ---
#
# ### 📊 Key Features:
#
# - The shape depends on **degrees of freedom (df)**.
# - Always **non-negative** (χ² ≥ 0).
# - Becomes more symmetric as df increases.
#
# ---
#
# ### 🧪 Common Uses in Statistics:
#
# | Use Case                          | Description                                              |
# |----------------------------------|----------------------------------------------------------|
# | **Goodness-of-fit test**         | Tests if observed frequencies match expected frequencies |
# | **Test for independence**        | Tests if two categorical variables are related (contingency table) |
# | **Variance test**                | Tests if sample variance matches a hypothesized value    |
#
# ---
#
# ### 📌 Chi-square Formula (for goodness-of-fit):
#
# $$
# \chi^2 = \sum \frac{(O_i - E_i)^2}{E_i}
# $$
#
# Where:
# - \( O_i \): Observed frequency
# - \( E_i \): Expected frequency
#
# ---
#
# ### ✅ Example Applications:
# - Do survey results follow a known distribution?
# - Are gender and product preference independent?
# - Is the variation in a process statistically significant?
#
# ---
#
# ### 📌 Important:
# Chi-square tests assume:
# - Observations are **independent**
# - Expected frequencies are **sufficiently large** (typically ≥ 5)
#
# ---
# ##18. ## 📊 What is the Chi-square Goodness of Fit Test, and How Is It Applied?
#
# ### 📌 What is the Chi-square Goodness of Fit Test?
#
# The **Chi-square goodness of fit test** is used to determine whether the **observed frequency distribution** of a categorical variable **matches an expected distribution**.
#
# ---
#
# ### 🧮 Test Statistic Formula:
#
# $$
# \chi^2 = \sum \frac{(O_i - E_i)^2}{E_i}
# $$
#
# Where:
# - \( O_i \): Observed frequency for category *i*
# - \( E_i \): Expected frequency for category *i*
#
# ---
#
# ### ✅ When to Use It:
#
# - You have **one categorical variable**
# - You want to test if the observed counts **fit a known distribution** (e.g., uniform, historical data, theoretical ratios)
#
# ---
#
# ### 🧪 Steps to Apply:
#
# 1. State hypotheses:
#    - H₀: The observed distribution fits the expected distribution
#    - H₁: The observed distribution does not fit
#
# 2. Calculate expected frequencies
#
# 3. Compute the Chi-square test statistic
#
# 4. Find the p-value and compare it to α (e.g., 0.05)
#
# 5. Make a decision:
#    - If p-value < α → Reject H₀
#    - If p-value ≥ α → Fail to reject H₀
#
# ---
#
# ### ⚠️ Assumptions:
# - Categories are **mutually exclusive**
# - **Expected frequency ≥ 5** in each category (for validity)
#
# ---
# ##19. What is the F-distribution, and When Is It Used in Hypothesis Testing?
#
# ### 📌 What is the F-distribution?
#
# The **F-distribution** is a right-skewed probability distribution used primarily to compare **two variances** or test **overall model significance** in regression and ANOVA.
#
# ---
#
# ### 🔢 Characteristics:
#
# - Always **positive** (F ≥ 0)
# - **Shape depends** on two parameters: degrees of freedom in numerator (df₁) and denominator (df₂)
# - Becomes more symmetric as degrees of freedom increase
#
# ---
#
# ### 🧪 Common Uses of the F-distribution:
#
# | Test/Use Case                  | Description                                                                 |
# |-------------------------------|-----------------------------------------------------------------------------|
# | **ANOVA (Analysis of Variance)** | Tests whether three or more group means are significantly different        |
# | **Test for Equality of Variances** | Compares variances of two populations                                       |
# | **Multiple Regression (overall F-test)** | Tests whether the regression model as a whole is significant            |
#
# ---
#
# ### 🧮 F-statistic Formula (ANOVA context):
#
# \[
# F = \frac{\text{Variance Between Groups}}{\text{Variance Within Groups}} = \frac{MSB}{MSW}
# \]
#
# Where:
# - MSB = Mean Square Between groups
# - MSW = Mean Square Within groups
#
# ---
#
# ### ✅ Decision Rule:
#
# - **H₀ (null)**: No difference in group means (or equal variances)
# - **H₁ (alt.)**: At least one mean is different (or variances differ)
# - If **F-statistic > critical value** or **p-value < α**, reject H₀
#
# ---
#
# ### ⚠️ Assumptions:
#
# - Data are normally distributed
# - Samples are independent
# - Variances are equal across groups (for ANOVA)
#
# ---
# ##20.  What is an ANOVA test, and what are its assumptions ?
#
# ### 📌 What is ANOVA?
#
# **ANOVA** (Analysis of Variance) is a statistical test used to determine whether there are **statistically significant differences between the means** of **three or more independent groups**.
#
# It uses the **F-distribution** to assess if the **between-group variance** is significantly larger than the **within-group variance**.
#
# ---
#
# ### 🧮 Hypotheses:
#
# - **H₀ (Null)**: All group means are equal (no difference)
# - **H₁ (Alternative)**: At least one group mean is different
#
# ---
#
# ### ✅ ANOVA Test Formula:
#
# $$
# F = \frac{MSB}{MSW}
# $$
#
# Where:
# - **MSB**: Mean Square Between (variance between group means)
# - **MSW**: Mean Square Within (variance within groups)
#
# ---
#
# ### 🧠 Assumptions of ANOVA:
#
# 1. **Independence** of observations
# 2. **Normality**: Data in each group should be approximately normally distributed
# 3. **Homogeneity of variances**: Groups should have similar variances (use Levene’s Test to check)
#
# ---
#
# ### 📌 Use Cases:
#
# - Compare test scores across 3 teaching methods
# - Analyze effectiveness of multiple diets
# - Compare product satisfaction across regions
#
# ---
#
# ### 🔍 Interpretation:
#
# - If **p-value < α** (e.g., 0.05), reject H₀ → At least one group mean is different
# - If **p-value ≥ α**, fail to reject H₀ → No significant difference between means
#
# ---
# ##21. What are the different types of ANOVA tests ?
#
#
# **ANOVA** (Analysis of Variance) is a family of statistical tests used to determine whether there are **significant differences between group means**. There are **different types of ANOVA** depending on the number of factors and the design of the experiment.
#
# ---
#
# ### 🔹 1. **One-Way ANOVA**
#
# - 📌 Compares the means of **3 or more independent groups** based on **1 independent variable (factor)**
# - ✅ Example: Compare average exam scores across 3 different teaching methods.
#
# ---
#
# ### 🔹 2. **Two-Way ANOVA (Factorial ANOVA)**
#
# - 📌 Tests the effects of **two independent variables (factors)** on one dependent variable.
# - Also examines if there is an **interaction** between the two factors.
# - ✅ Example: Study the effects of **teaching method** and **gender** on test scores.
#
# ---
#
# ### 🔹 3. **Repeated Measures ANOVA**
#
# - 📌 Used when the **same subjects** are measured multiple times under different conditions or time points.
# - ✅ Example: Test scores measured **before, during, and after** training on the same group.
#
# ---
#
# ### 🔹 4. **Mixed-Design ANOVA (Split-Plot ANOVA)**
#
# - 📌 Combines **between-subject** (e.g., different groups) and **within-subject** (e.g., repeated measures) factors.
# - ✅ Example: Compare different treatment groups over multiple time points.
#
# ---
#
# ### 🧾 Summary Table:
#
# | ANOVA Type               | Factors          | Groups Repeated? | Use Case                                    |
# |--------------------------|------------------|------------------|----------------------------------------------|
# | **One-Way ANOVA**        | 1                | No               | Compare means of ≥3 independent groups       |
# | **Two-Way ANOVA**        | 2                | No               | Assess interaction between 2 independent vars|
# | **Repeated Measures**    | 1 (or more)      | Yes              | Track same group over time                   |
# | **Mixed-Design ANOVA**   | 2 (mixed)        | Some Yes/No      | Compare groups across repeated measures      |
#
# ---
#
# ### 📌 Why So Many?
#
# Each type is designed to **fit different experimental setups** and answer different kinds of questions about the relationships between variables.
#
# ##22. What is the F-test, and How Does It Relate to Hypothesis Testing?
#
# ### 📌 What is the F-test?
#
# The **F-test** is a statistical test used to compare **two variances** or to evaluate whether a group of variables **explains a significant amount of variation** in a model.
#
# It is based on the **F-distribution**, which arises when comparing **ratios of variances**.
#
# ---
#
# ### 🎯 Common Uses of the F-test:
#
# | Type of F-test             | Purpose                                                       |
# |----------------------------|---------------------------------------------------------------|
# | **ANOVA F-test**           | Compares variances across **three or more group means**       |
# | **Variance Ratio Test**    | Compares **two population variances**                         |
# | **Regression F-test**      | Tests if the **overall regression model** is significant      |
#
# ---
#
# ### 🧮 F-statistic Formula (general form):
#
# $$
# F = \frac{\text{Variance Between Groups}}{\text{Variance Within Groups}} = \frac{MSB}{MSW}
# $$
#
# Or for comparing two variances:
#
# $$
# F = \frac{s_1^2}{s_2^2}
# $$
#
# Where \( s_1^2 \) and \( s_2^2 \) are sample variances from two independent groups.
#
# ---
#
# ### ✅ Hypothesis Testing with F-test:
#
# - **H₀ (Null Hypothesis)**:
#   - ANOVA: All group means are equal
#   - Variance test: Both groups have equal variances
#   - Regression: All regression coefficients = 0 (no effect)
#
# - **H₁ (Alternative Hypothesis)**: At least one group differs (ANOVA), variances are not equal, or model is significant
#
# - Reject H₀ if:
#   - \( F \) is **greater than the critical value** from F-distribution
#   - or **p-value < significance level (α)** (e.g., 0.05)
#
# ---
#
# ### 🔍 Summary:
#
# The **F-test is central to ANOVA and regression analysis**, making it a powerful tool in hypothesis testing when comparing multiple groups or evaluating overall model fit.
#
# #Practical Questions:-
#
# ##1. Write a Python program to generate a random variable and display its value.

# %%
import random

# Generate a random float between 0 and 1
random_variable = random.random()

# Display the value
print("🎲 Random Variable (0 to 1):", random_variable)
# Out:
# 🎲 Random Variable (0 to 1): 0.5098390526166708

# %% [markdown]
# ##2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).

# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Define range for discrete uniform distribution (e.g., die roll: 1 to 6)
low = 1
high = 7  # scipy randint is [low, high)

# Generate PMF values
x = np.arange(low, high)
pmf = randint.pmf(x, low, high)

# Plot the PMF
plt.figure(figsize=(8, 5))
markerline, stemlines, baseline = plt.stem(x, pmf, basefmt=" ")
plt.setp(markerline, 'markerfacecolor', 'blue')
plt.xlabel("x (Discrete Values)")
plt.ylabel("P(X = x)")
plt.title("🎲 PMF of Discrete Uniform Distribution (1 to 6)")
plt.xticks(x)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ##3.  Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.

# %%
def bernoulli_pdf(x, p):
    """
    Calculate the PDF (PMF) of a Bernoulli distribution.

    Parameters:
    x : int (0 or 1)
        Outcome (0 = failure, 1 = success)
    p : float (0 ≤ p ≤ 1)
        Probability of success

    Returns:
    float : Probability of x under Bernoulli(p)
    """
    if x not in [0, 1]:
        raise ValueError("x must be 0 or 1 for a Bernoulli distribution")
    if not (0 <= p <= 1):
        raise ValueError("p must be between 0 and 1")
    return p if x == 1 else (1 - p)

# Example usage:
print("P(X = 1) when p = 0.7:", bernoulli_pdf(1, 0.7))
print("P(X = 0) when p = 0.7:", bernoulli_pdf(0, 0.7))
# Out:
# P(X = 1) when p = 0.7: 0.7
# P(X = 0) when p = 0.7: 0.30000000000000004

# %% [markdown]
# ##4.  Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# Parameters for the binomial distribution
n = 10        # number of trials
p = 0.5       # probability of success
size = 1000   # number of simulations

# Simulate binomial random variables
samples = np.random.binomial(n=n, p=p, size=size)

# Plot histogram of the simulated values
plt.figure(figsize=(8, 5))
plt.hist(samples, bins=np.arange(-0.5, n + 1.5, 1), density=True, edgecolor='black', alpha=0.7)

# Overlay theoretical PMF for comparison
x = np.arange(0, n + 1)
pmf = binom.pmf(x, n, p)
plt.plot(x, pmf, 'o-', color='red', label='Theoretical PMF')

# Labels and title
plt.title(f"🎯 Binomial Distribution (n={n}, p={p})")
plt.xlabel("Number of Successes")
plt.ylabel("Probability")
plt.xticks(range(0, n+1))
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ##5.  Create a Poisson distribution and visualize it using Python.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Parameters
mu = 4  # average number of events (λ)

# Range of x values
x = np.arange(0, 15)

# Compute Poisson PMF
pmf = poisson.pmf(x, mu)

# Plot
plt.figure(figsize=(8, 5))
plt.bar(x, pmf, color='skyblue', edgecolor='black')
plt.xlabel("Number of Events (k)")
plt.ylabel("P(X = k)")
plt.title(f"📊 Poisson Distribution (λ = {mu})")
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.xticks(x)
plt.show()

# %% [markdown]
# ##6. Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Parameters for discrete uniform distribution (e.g., integers from 1 to 6)
low = 1
high = 7  # Upper bound is exclusive in scipy's randint

# Define x values in the range
x = np.arange(low, high)

# Calculate CDF values
cdf_values = randint.cdf(x, low, high)

# Plot CDF
plt.figure(figsize=(8, 5))
plt.step(x, cdf_values, where='post', color='purple', label='CDF')
plt.scatter(x, cdf_values, color='purple')
plt.xlabel("x (Discrete Values)")
plt.ylabel("P(X ≤ x)")
plt.title("📈 CDF of Discrete Uniform Distribution (1 to 6)")
plt.xticks(x)
plt.yticks(np.linspace(0, 1, high - low + 1))
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.show()

# %% [markdown]
# ##7.  Generate a continuous uniform distribution using NumPy and visualize it.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform

# Define the range of the distribution
a = 0      # Lower bound
b = 10     # Upper bound
size = 1000  # Number of random samples

# Generate samples from the continuous uniform distribution
samples = np.random.uniform(a, b, size=size)

# Plot histogram of the sampled data
plt.figure(figsize=(8, 5))
count, bins, ignored = plt.hist(samples, bins=30, density=True, alpha=0.7, edgecolor='black', label="Sample Histogram")

# Plot the theoretical PDF
x = np.linspace(a, b, 1000)
pdf = uniform.pdf(x, loc=a, scale=b - a)
plt.plot(x, pdf, 'r-', lw=2, label='Theoretical PDF')

# Decorate the plot
plt.title("📊 Continuous Uniform Distribution (a = 0, b = 10)")
plt.xlabel("Value")
plt.ylabel("Density")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ##8.  Simulate data from a normal distribution and plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters of the normal distribution
mu = 0     # Mean
sigma = 1  # Standard deviation
size = 1000  # Number of samples

# Simulate data from normal distribution
samples = np.random.normal(loc=mu, scale=sigma, size=size)

# Plot histogram
plt.figure(figsize=(8, 5))
count, bins, ignored = plt.hist(samples, bins=30, density=True, alpha=0.7, edgecolor='black', label='Sampled Data')

# Plot theoretical PDF
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)
pdf = norm.pdf(x, loc=mu, scale=sigma)
plt.plot(x, pdf, 'r-', lw=2, label='Theoretical PDF')

# Decorate the plot
plt.title("📈 Normal Distribution (μ = 0, σ = 1)")
plt.xlabel("Value")
plt.ylabel("Density")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ##9.  Write a Python function to calculate Z-scores from a dataset and plot them.

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_z_scores(data):
    """
    Calculates Z-scores for a dataset.

    Parameters:
        data (list or np.array): Input numeric data

    Returns:
        np.array: Z-scores of the data
    """
    mean = np.mean(data)
    std_dev = np.std(data)
    z_scores = (data - mean) / std_dev
    return z_scores

# Simulate example data
np.random.seed(0)
data = np.random.normal(loc=50, scale=10, size=100)

# Calculate Z-scores
z_scores = calculate_z_scores(data)

# Plot Z-scores
plt.figure(figsize=(10, 5))
plt.plot(z_scores, marker='o', linestyle='-', color='blue')
plt.axhline(y=0, color='gray', linestyle='--')
plt.axhline(y=1, color='red', linestyle='--', linewidth=0.8, label='1 SD')
plt.axhline(y=-1, color='red', linestyle='--', linewidth=0.8)
plt.title("📊 Z-scores of the Dataset")
plt.xlabel("Index")
plt.ylabel("Z-score")
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.show()

# %% [markdown]
# ##10.  Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set parameters
population_size = 100000
sample_size = 30         # Number of data points per sample
num_samples = 1000       # Number of samples to draw
lambda_param = 1         # For exponential distribution

# Step 1: Generate a non-normal population (Exponential distribution)
population = np.random.exponential(scale=1/lambda_param, size=population_size)

# Step 2: Draw multiple samples and calculate sample means
sample_means = []

for _ in range(num_samples):
    sample = np.random.choice(population, size=sample_size, replace=False)
    sample_means.append(np.mean(sample))

# Step 3: Plot the sampling distribution of the sample means
plt.figure(figsize=(10, 5))
plt.hist(sample_means, bins=30, density=True, alpha=0.7, edgecolor='black')
plt.title("📈 Central Limit Theorem - Sampling Distribution of Sample Means")
plt.xlabel("Sample Mean")
plt.ylabel("Probability Density")
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ##11. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Step 1: Parameters
population_mean = 100
population_std = 15
sample_size = 30
num_samples = 1000

# Step 2: Generate sample means from normal distribution
sample_means = []
for _ in range(num_samples):
    sample = np.random.normal(loc=population_mean, scale=population_std, size=sample_size)
    sample_means.append(np.mean(sample))

# Step 3: Plot the sampling distribution of the sample means
plt.figure(figsize=(10, 5))
plt.hist(sample_means, bins=30, density=True, alpha=0.7, edgecolor='black', label='Sample Means Histogram')

# Overlay theoretical normal distribution
x = np.linspace(min(sample_means), max(sample_means), 1000)
pdf = norm.pdf(x, loc=population_mean, scale=population_std/np.sqrt(sample_size))
plt.plot(x, pdf, 'r--', lw=2, label='Theoretical Normal PDF')

# Plot formatting
plt.title("📈 Central Limit Theorem - Sample Means from Normal Distribution")
plt.xlabel("Sample Mean")
plt.ylabel("Probability Density")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ##12.  Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal_distribution():
    """
    Calculates and plots the standard normal distribution (mean = 0, std = 1).
    """
    # Generate x values
    x = np.linspace(-4, 4, 1000)

    # Calculate PDF of standard normal
    pdf = norm.pdf(x, loc=0, scale=1)

    # Plot the PDF
    plt.figure(figsize=(8, 5))
    plt.plot(x, pdf, color='blue', lw=2, label='Standard Normal PDF')
    plt.fill_between(x, pdf, alpha=0.2)
    plt.title("📈 Standard Normal Distribution (μ = 0, σ = 1)")
    plt.xlabel("Z-score")
    plt.ylabel("Probability Density")
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.legend()
    plt.show()

# Call the function
plot_standard_normal_distribution()

# %% [markdown]
# ##13.  Generate random variables and calculate their corresponding probabilities using the binomial distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# Parameters for binomial distribution
n = 10   # number of trials
p = 0.5  # probability of success

# Generate random binomial outcomes
random_outcomes = np.random.binomial(n=n, p=p, size=20)
print("🎲 Random Binomial Outcomes:", random_outcomes)

# PMF calculation
x = np.arange(0, n+1)
pmf_values = binom.pmf(x, n, p)

# Plot PMF (fixed version)
plt.figure(figsize=(8, 5))
plt.stem(x, pmf_values, basefmt=" ")
plt.xlabel("Number of Successes (x)")
plt.ylabel("P(X = x)")
plt.title("📊 Binomial Distribution PMF (n=10, p=0.5)")
plt.xticks(x)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
# Out:
# 🎲 Random Binomial Outcomes: [4 6 6 5 7 4 3 5 0 2 6 6 3 5 7 4 5 5 3 4]

# %% [markdown]
# ##14. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_z_score(x, mean, std_dev):
    """Calculate the Z-score of a data point."""
    return (x - mean) / std_dev

# Sample input
x_value = 85
mean = 70
std_dev = 10

# Calculate Z-score
z = calculate_z_score(x_value, mean, std_dev)
print(f"Z-score for x = {x_value}: {z:.2f}")

# Plot standard normal distribution with Z marked
x = np.linspace(-4, 4, 1000)
pdf = norm.pdf(x, 0, 1)

plt.figure(figsize=(10, 5))
plt.plot(x, pdf, label='Standard Normal PDF', color='blue')
plt.fill_between(x, pdf, where=(x <= z), color='skyblue', alpha=0.5, label=f'Area ≤ Z ({z:.2f})')
plt.axvline(x=z, color='red', linestyle='--', label=f'Z = {z:.2f}')
plt.title("📈 Standard Normal Distribution with Marked Z-score")
plt.xlabel("Z-score")
plt.ylabel("Density")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
# Out:
# Z-score for x = 85: 1.50

# %% [markdown]
# ##15.  Implement hypothesis testing using Z-statistics for a sample dataset.

# %%
import numpy as np
from scipy.stats import norm

# Sample data
sample = np.array([68, 70, 72, 71, 69, 73, 70, 68, 72, 74])
sample_mean = np.mean(sample)
n = len(sample)

# Known population parameters
mu_0 = 70     # population mean (hypothesized)
sigma = 3     # known population standard deviation
alpha = 0.05  # significance level

# Step 1: Calculate Z-statistic
z_stat = (sample_mean - mu_0) / (sigma / np.sqrt(n))

# Step 2: Calculate p-value for two-tailed test
p_value = 2 * (1 - norm.cdf(abs(z_stat)))

# Step 3: Print results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-statistic: {z_stat:.3f}")
print(f"P-value: {p_value:.4f}")

# Step 4: Decision
if p_value < alpha:
    print("🔴 Reject the Null Hypothesis (H₀): Significant difference.")
else:
    print("🟢 Fail to Reject the Null Hypothesis (H₀): No significant difference.")
# Out:
# Sample Mean: 70.70
# Z-statistic: 0.738
# P-value: 0.4606
# 🟢 Fail to Reject the Null Hypothesis (H₀): No significant difference.

# %% [markdown]
# ##16.  Create a confidence interval for a dataset using Python and interpret the result.

# %%
import numpy as np
from scipy import stats

# Sample data
data = np.array([68, 70, 72, 71, 69, 73, 70, 68, 72, 74])
n = len(data)
mean = np.mean(data)
std_dev = np.std(data, ddof=1)  # sample standard deviation
confidence_level = 0.95
alpha = 1 - confidence_level

# Get the t-critical value
t_critical = stats.t.ppf(1 - alpha/2, df=n-1)

# Calculate margin of error
margin_of_error = t_critical * (std_dev / np.sqrt(n))

# Calculate confidence interval
ci_lower = mean - margin_of_error
ci_upper = mean + margin_of_error

# Display results
print(f"Sample Mean: {mean:.2f}")
print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")
print("We are 95% confident that the true population mean lies within this interval.")
# Out:
# Sample Mean: 70.70
# 95% Confidence Interval: (69.23, 72.17)
# We are 95% confident that the true population mean lies within this interval.

# %% [markdown]
# ##17.  Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.

# %%
import numpy as np
from scipy import stats

# Step 1: Generate random data from a normal distribution
np.random.seed(42)
data = np.random.normal(loc=100, scale=15, size=30)  # mean=100, std=15, n=30

# Step 2: Calculate sample statistics
sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)
n = len(data)
confidence = 0.95
alpha = 1 - confidence

# Step 3: Calculate t-critical value and margin of error
t_critical = stats.t.ppf(1 - alpha/2, df=n-1)
margin_of_error = t_critical * (sample_std / np.sqrt(n))

# Step 4: Confidence Interval
ci_lower = sample_mean - margin_of_error
ci_upper = sample_mean + margin_of_error

# Step 5: Display results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"95% Confidence Interval for Mean: ({ci_lower:.2f}, {ci_upper:.2f})")
print("✅ Interpretation: We are 95% confident that the true population mean lies within this interval.")
# Out:
# Sample Mean: 97.18
# 95% Confidence Interval for Mean: (92.14, 102.22)
# ✅ Interpretation: We are 95% confident that the true population mean lies within this interval.

# %% [markdown]
# ##18.  Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Define parameters for the normal distribution
mu = 0       # Mean
sigma = 1    # Standard deviation

# Generate x values
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)

# Calculate PDF values
pdf = norm.pdf(x, loc=mu, scale=sigma)

# Plot the PDF
plt.figure(figsize=(8, 5))
plt.plot(x, pdf, color='blue', lw=2, label=f'N(μ={mu}, σ={sigma})')
plt.fill_between(x, pdf, alpha=0.2)
plt.title("📈 Normal Distribution - Probability Density Function (PDF)")
plt.xlabel("x")
plt.ylabel("Density")
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.show()

# %% [markdown]
# ##19.  Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Set Poisson distribution parameter
lambda_val = 4  # average number of events

# Define range of x values
x = np.arange(0, 15)

# Calculate CDF values
cdf = poisson.cdf(x, mu=lambda_val)

# Plot the CDF
plt.figure(figsize=(8, 5))
plt.step(x, cdf, where='post', label=f'Poisson CDF (λ = {lambda_val})', color='green')
plt.scatter(x, cdf, color='green')
plt.title("📈 Cumulative Distribution Function (CDF) - Poisson Distribution")
plt.xlabel("x (Number of Events)")
plt.ylabel("P(X ≤ x)")
plt.grid(True, linestyle='--', alpha=0.5)
plt.xticks(x)
plt.legend()
plt.show()

# %% [markdown]
# ##20.  Simulate a random variable using a continuous uniform distribution and calculate its expected value

# %%
import numpy as np

# Parameters for uniform distribution
a = 5   # lower bound
b = 15  # upper bound
n = 10000  # number of samples

# Simulate random variable
samples = np.random.uniform(low=a, high=b, size=n)

# Theoretical expected value
expected_value_theoretical = (a + b) / 2

# Empirical (sample) mean
expected_value_empirical = np.mean(samples)

# Display results
print(f"🎯 Theoretical Expected Value: {expected_value_theoretical}")
print(f"📊 Empirical Mean from Simulation: {expected_value_empirical:.4f}")
# Out:
# 🎯 Theoretical Expected Value: 10.0
# 📊 Empirical Mean from Simulation: 9.9436

# %% [markdown]
# ##21.  Write a Python program to compare the standard deviations of two datasets and visualize the difference.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Generate two datasets
np.random.seed(0)
data1 = np.random.normal(loc=50, scale=5, size=1000)   # lower SD
data2 = np.random.normal(loc=50, scale=15, size=1000)  # higher SD

# Step 2: Calculate standard deviations
std1 = np.std(data1, ddof=1)
std2 = np.std(data2, ddof=1)

print(f"📊 Standard Deviation of Dataset 1: {std1:.2f}")
print(f"📊 Standard Deviation of Dataset 2: {std2:.2f}")

# Step 3: Visualize the datasets
plt.figure(figsize=(10, 5))
plt.hist(data1, bins=30, alpha=0.6, label=f'Dataset 1 (SD={std1:.2f})', color='blue', edgecolor='black')
plt.hist(data2, bins=30, alpha=0.6, label=f'Dataset 2 (SD={std2:.2f})', color='orange', edgecolor='black')
plt.title("📈 Comparison of Distributions with Different Standard Deviations")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()
# Out:
# 📊 Standard Deviation of Dataset 1: 4.94
# 📊 Standard Deviation of Dataset 2: 14.53

# %% [markdown]
# ##22. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.

# %%
import numpy as np

# Step 1: Generate data from a normal distribution
np.random.seed(42)
data = np.random.normal(loc=100, scale=15, size=1000)

# Step 2: Calculate Range
data_range = np.max(data) - np.min(data)

# Step 3: Calculate Interquartile Range (IQR)
q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)
iqr = q3 - q1

# Step 4: Display results
print(f"📈 Range of the data: {data_range:.2f}")
print(f"🔳 Q1 (25th percentile): {q1:.2f}")
print(f"🔳 Q3 (75th percentile): {q3:.2f}")
print(f"📦 Interquartile Range (IQR): {iqr:.2f}")
# Out:
# 📈 Range of the data: 106.41
# 🔳 Q1 (25th percentile): 90.29
# 🔳 Q3 (75th percentile): 109.72
# 📦 Interquartile Range (IQR): 19.43

# %% [markdown]
# ##23.  Implement Z-score normalization on a dataset and visualize its transformation.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Generate synthetic data (normal distribution)
np.random.seed(1)
data = np.random.normal(loc=50, scale=10, size=1000)

# Step 2: Z-score normalization
mean = np.mean(data)
std_dev = np.std(data)
z_scores = (data - mean) / std_dev

# Step 3: Plot original vs normalized
plt.figure(figsize=(12, 5))

# Original distribution
plt.subplot(1, 2, 1)
plt.hist(data, bins=30, color='skyblue', edgecolor='black')
plt.title("📊 Original Data")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.grid(True, linestyle='--', alpha=0.5)

# Normalized distribution
plt.subplot(1, 2, 2)
plt.hist(z_scores, bins=30, color='lightgreen', edgecolor='black')
plt.title("📈 Z-score Normalized Data")
plt.xlabel("Z-score")
plt.ylabel("Frequency")
plt.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# Display mean and std of transformed data
print(f"Original Mean: {mean:.2f}, Std Dev: {std_dev:.2f}")
print(f"Z-score Mean: {np.mean(z_scores):.2f}, Std Dev: {np.std(z_scores):.2f}")
# Out:
# Original Mean: 50.39, Std Dev: 9.81
# Z-score Mean: 0.00, Std Dev: 1.00

# %% [markdown]
# ##24. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.

# %%
import numpy as np
from scipy.stats import skew, kurtosis

def analyze_skewness_kurtosis(size=1000, mean=0, std=1):
    # Generate normal distribution data
    data = np.random.normal(loc=mean, scale=std, size=size)

    # Calculate skewness and kurtosis
    data_skewness = skew(data)
    data_kurtosis = kurtosis(data)  # by default: excess kurtosis (normal = 0)

    # Print results
    print(f"Generated Data (N={size}, μ={mean}, σ={std}):")
    print(f"📐 Skewness: {data_skewness:.4f}")
    print(f"🎯 Kurtosis (Excess): {data_kurtosis:.4f}")

# Run the function
analyze_skewness_kurtosis()
# Out:
# Generated Data (N=1000, μ=0, σ=1):
# 📐 Skewness: -0.0032
# 🎯 Kurtosis (Excess): -0.1561

# %% [markdown]
# #Practical Questions Part-2:-
#
# ##1. Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results.

# %%
import numpy as np
from scipy.stats import norm

# Step 1: Sample data (you can customize this)
sample = np.array([68, 72, 70, 71, 69, 74, 73, 70, 67, 72])
sample_mean = np.mean(sample)
n = len(sample)

# Step 2: Known population parameters
population_mean = 70
population_std = 4   # Known σ
alpha = 0.05         # Significance level

# Step 3: Z-test statistic
z_stat = (sample_mean - population_mean) / (population_std / np.sqrt(n))

# Step 4: Calculate p-value (two-tailed)
p_value = 2 * (1 - norm.cdf(abs(z_stat)))

# Step 5: Display results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-statistic: {z_stat:.3f}")
print(f"P-value: {p_value:.4f}")

# Step 6: Interpretation
if p_value < alpha:
    print("🔴 Reject the Null Hypothesis: Significant difference found.")
else:
    print("🟢 Fail to Reject the Null Hypothesis: No significant difference found.")
# Out:
# Sample Mean: 70.60
# Z-statistic: 0.474
# P-value: 0.6353
# 🟢 Fail to Reject the Null Hypothesis: No significant difference found.

# %% [markdown]
# ##2.  Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python.

# %%
import numpy as np
from scipy.stats import norm

# Step 1: Simulate sample data from a normal distribution
np.random.seed(0)
sample = np.random.normal(loc=105, scale=15, size=40)  # true mean = 105
sample_mean = np.mean(sample)
n = len(sample)

# Step 2: Known population values (assumed)
population_mean = 100
population_std = 15
alpha = 0.05

# Step 3: Calculate Z-statistic
z_stat = (sample_mean - population_mean) / (population_std / np.sqrt(n))

# Step 4: Calculate two-tailed P-value
p_value = 2 * (1 - norm.cdf(abs(z_stat)))

# Step 5: Output results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-statistic: {z_stat:.3f}")
print(f"P-value: {p_value:.4f}")

# Step 6: Interpretation
if p_value < alpha:
    print("🔴 Reject the Null Hypothesis: Significant difference found.")
else:
    print("🟢 Fail to Reject the Null Hypothesis: No significant difference found.")
# Out:
# Sample Mean: 109.69
# Z-statistic: 4.085
# P-value: 0.0000
# 🔴 Reject the Null Hypothesis: Significant difference found.

# %% [markdown]
# ##3.  Implement a one-sample Z-test using Python to compare the sample mean with the population mean.

# %%
import numpy as np
from scipy.stats import norm

# Step 1: Sample data
sample = np.array([102, 98, 101, 100, 97, 103, 105, 99, 104, 100])
sample_mean = np.mean(sample)
n = len(sample)

# Step 2: Known population parameters
population_mean = 100
population_std = 5  # Known σ
alpha = 0.05        # Significance level

# Step 3: Z-test calculation
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(n))
p_value = 2 * (1 - norm.cdf(abs(z_score)))  # two-tailed test

# Step 4: Output
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-score: {z_score:.3f}")
print(f"P-value: {p_value:.4f}")

# Step 5: Decision
if p_value < alpha:
    print("🔴 Reject the Null Hypothesis: Sample mean is significantly different from population mean.")
else:
    print("🟢 Fail to Reject the Null Hypothesis: No significant difference.")
# Out:
# Sample Mean: 100.90
# Z-score: 0.569
# P-value: 0.5692
# 🟢 Fail to Reject the Null Hypothesis: No significant difference.

# %% [markdown]
# ##4.  Perform a two-tailed Z-test using Python and visualize the decision region on a plot.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Sample data
sample = np.array([51, 49, 52, 50, 48, 53, 54, 50, 49, 52])
sample_mean = np.mean(sample)
n = len(sample)

# Population parameters
population_mean = 50
population_std = 3
alpha = 0.05

# Z-statistic
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(n))
p_value = 2 * (1 - norm.cdf(abs(z_score)))

# Decision
decision = "🔴 Reject H₀" if p_value < alpha else "🟢 Fail to Reject H₀"

# Print results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-score: {z_score:.3f}")
print(f"P-value: {p_value:.4f}")
print(f"Decision: {decision}")

# Visualization
z_values = np.linspace(-4, 4, 500)
pdf = norm.pdf(z_values)

z_critical = norm.ppf(1 - alpha/2)

plt.figure(figsize=(10, 5))
plt.plot(z_values, pdf, label="Standard Normal Distribution", color="blue")
plt.axvline(z_critical, color="red", linestyle="--", label=f"Critical Value (+/- {z_critical:.2f})")
plt.axvline(-z_critical, color="red", linestyle="--")
plt.axvline(z_score, color="green", linestyle="-", label=f"Z-score = {z_score:.2f}")

# Fill critical regions
plt.fill_between(z_values, 0, pdf, where=(z_values <= -z_critical) | (z_values >= z_critical),
                 color='red', alpha=0.3, label="Rejection Region (α=0.05)")

plt.title("📊 Two-Tailed Z-Test: Decision Region")
plt.xlabel("Z-value")
plt.ylabel("Probability Density")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()
# Out:
# Sample Mean: 50.80
# Z-score: 0.843
# P-value: 0.3991
# Decision: 🟢 Fail to Reject H₀

# %% [markdown]
# ##5.  Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def visualize_type1_type2_errors(mu_null=100, mu_alt=105, sigma=10, n=50, alpha=0.05):
    # Standard error
    se = sigma / np.sqrt(n)

    # Critical value for two-tailed test
    z_critical = norm.ppf(1 - alpha/2)
    margin = z_critical * se

    # Rejection regions under H0
    lower_crit = mu_null - margin
    upper_crit = mu_null + margin

    # x-values for plotting
    x = np.linspace(mu_null - 4*se, mu_alt + 4*se, 1000)

    # PDFs
    h0_pdf = norm.pdf(x, loc=mu_null, scale=se)
    h1_pdf = norm.pdf(x, loc=mu_alt, scale=se)

    # Plot distributions
    plt.figure(figsize=(12, 6))
    plt.plot(x, h0_pdf, label="H₀: μ = {}".format(mu_null), color="blue")
    plt.plot(x, h1_pdf, label="H₁: μ = {}".format(mu_alt), color="green")

    # Fill Type I error region (α) — area under H₀ in rejection zone
    plt.fill_between(x, 0, h0_pdf, where=(x < lower_crit) | (x > upper_crit), color='red', alpha=0.3, label="Type I Error (α)")

    # Fill Type II error region (β) — area under H₁ in acceptance zone
    plt.fill_between(x, 0, h1_pdf, where=(x >= lower_crit) & (x <= upper_crit), color='orange', alpha=0.3, label="Type II Error (β)")

    # Critical lines
    plt.axvline(lower_crit, color='red', linestyle='--')
    plt.axvline(upper_crit, color='red', linestyle='--')

    # Labels and legend
    plt.title("📊 Visualization of Type I (α) and Type II (β) Errors")
    plt.xlabel("Sample Mean")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.show()

# Run the function
visualize_type1_type2_errors()

# %% [markdown]
# ##6.  Write a Python program to perform an independent T-test and interpret the results.

# %%
import numpy as np
from scipy.stats import ttest_ind

# Step 1: Simulate two independent samples
np.random.seed(42)
group1 = np.random.normal(loc=100, scale=10, size=30)
group2 = np.random.normal(loc=105, scale=12, size=30)

# Step 2: Perform independent T-test (Welch's T-test by default)
t_stat, p_value = ttest_ind(group1, group2, equal_var=False)

# Step 3: Output results
print("Group 1 Mean:", np.mean(group1))
print("Group 2 Mean:", np.mean(group2))
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Step 4: Interpretation
alpha = 0.05
if p_value < alpha:
    print("🔴 Reject the Null Hypothesis: The group means are significantly different.")
else:
    print("🟢 Fail to Reject the Null Hypothesis: No significant difference in means.")
# Out:
# Group 1 Mean: 98.11853104148962
# Group 2 Mean: 103.54605035652068
# T-statistic: -2.0720
# P-value: 0.0429
# 🔴 Reject the Null Hypothesis: The group means are significantly different.

# %% [markdown]
# ##7.  Perform a paired sample T-test using Python and visualize the comparison results.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_rel

# Step 1: Simulate paired data (e.g., pre-test and post-test scores)
np.random.seed(0)
before = np.random.normal(loc=70, scale=5, size=30)
after = before + np.random.normal(loc=2, scale=3, size=30)  # slight improvement

# Step 2: Perform paired T-test
t_stat, p_value = ttest_rel(before, after)

# Step 3: Output
print(f"Mean Before: {np.mean(before):.2f}")
print(f"Mean After: {np.mean(after):.2f}")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Step 4: Interpretation
alpha = 0.05
if p_value < alpha:
    print("🔴 Reject the Null Hypothesis: Significant change detected between paired samples.")
else:
    print("🟢 Fail to Reject the Null Hypothesis: No significant change detected.")

# Step 5: Visualize the paired changes
plt.figure(figsize=(10, 5))
plt.plot(before, 'o-', label="Before", color='blue')
plt.plot(after, 's--', label="After", color='green')
plt.title("📊 Paired Sample Values: Before vs After")
plt.xlabel("Subject")
plt.ylabel("Score")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# Mean Before: 72.21
# Mean After: 73.35
# T-statistic: -2.2595
# P-value: 0.0315
# 🔴 Reject the Null Hypothesis: Significant change detected between paired samples.

# %% [markdown]
# ##8.  Simulate data and perform both Z-test and T-test, then compare the results using Python.

# %%
import numpy as np
from scipy.stats import norm, t

# Step 1: Simulate data
np.random.seed(123)
sample = np.random.normal(loc=102, scale=15, size=25)
sample_mean = np.mean(sample)
sample_std = np.std(sample, ddof=1)
n = len(sample)

# Hypothesized population mean
mu_0 = 100
alpha = 0.05

# --- Z-test (assuming known population std)
pop_std = 15  # known population std dev
z_stat = (sample_mean - mu_0) / (pop_std / np.sqrt(n))
z_pval = 2 * (1 - norm.cdf(abs(z_stat)))

# --- T-test (sample std used)
t_stat = (sample_mean - mu_0) / (sample_std / np.sqrt(n))
t_pval = 2 * (1 - t.cdf(abs(t_stat), df=n-1))

# Step 3: Print comparison
print(f"Sample Mean: {sample_mean:.2f}, Sample Std Dev: {sample_std:.2f}, n = {n}")
print("\n--- Z-test (σ known) ---")
print(f"Z-statistic: {z_stat:.3f}")
print(f"P-value: {z_pval:.4f}")
print("Decision:", "🔴 Reject H₀" if z_pval < alpha else "🟢 Fail to Reject H₀")

print("\n--- T-test (σ unknown) ---")
print(f"T-statistic: {t_stat:.3f}")
print(f"P-value: {t_pval:.4f}")
print("Decision:", "🔴 Reject H₀" if t_pval < alpha else "🟢 Fail to Reject H₀")
# Out:
# Sample Mean: 104.10, Sample Std Dev: 18.48, n = 25
#
# --- Z-test (σ known) ---
# Z-statistic: 1.367
# P-value: 0.1716
# Decision: 🟢 Fail to Reject H₀
#
# --- T-test (σ unknown) ---
# T-statistic: 1.110
# P-value: 0.2780
# Decision: 🟢 Fail to Reject H₀

# %% [markdown]
# ##9.  Write a Python function to calculate the confidence interval for a sample mean and explain its significance.

# %%
import numpy as np
from scipy.stats import t

def confidence_interval(data, confidence=0.95):
    n = len(data)
    sample_mean = np.mean(data)
    sample_std = np.std(data, ddof=1)
    se = sample_std / np.sqrt(n)

    # t-critical value for two-tailed test
    t_crit = t.ppf((1 + confidence) / 2, df=n-1)

    # Margin of error
    margin = t_crit * se

    # CI range
    lower = sample_mean - margin
    upper = sample_mean + margin

    print(f"Sample Mean: {sample_mean:.2f}")
    print(f"Sample Std Dev: {sample_std:.2f}")
    print(f"{int(confidence*100)}% Confidence Interval: ({lower:.2f}, {upper:.2f})")
    print("\n🧠 Interpretation:")
    print(f"We are {int(confidence*100)}% confident that the true population mean lies between {lower:.2f} and {upper:.2f}.")

# Example usage
np.random.seed(42)
sample_data = np.random.normal(loc=100, scale=15, size=30)
confidence_interval(sample_data)
# Out:
# Sample Mean: 97.18
# Sample Std Dev: 13.50
# 95% Confidence Interval: (92.14, 102.22)
#
# 🧠 Interpretation:
# We are 95% confident that the true population mean lies between 92.14 and 102.22.

# %% [markdown]
# ##10. Write a Python program to calculate the margin of error for a given confidence level using sample data.

# %%
import numpy as np
from scipy.stats import t

def calculate_margin_of_error(data, confidence=0.95):
    n = len(data)
    sample_std = np.std(data, ddof=1)
    se = sample_std / np.sqrt(n)

    # Get t-critical value
    t_critical = t.ppf((1 + confidence) / 2, df=n-1)

    # Calculate margin of error
    margin_of_error = t_critical * se

    print(f"Sample Size (n): {n}")
    print(f"Sample Standard Deviation (s): {sample_std:.2f}")
    print(f"Confidence Level: {int(confidence * 100)}%")
    print(f"Margin of Error: ±{margin_of_error:.2f}")

    print("\n📌 Interpretation:")
    print(f"The true population mean is expected to lie within ±{margin_of_error:.2f} units of the sample mean.")

# Example usage
np.random.seed(1)
sample_data = np.random.normal(loc=70, scale=12, size=35)
calculate_margin_of_error(sample_data)
# Out:
# Sample Size (n): 35
# Sample Standard Deviation (s): 11.68
# Confidence Level: 95%
# Margin of Error: ±4.01
#
# 📌 Interpretation:
# The true population mean is expected to lie within ±4.01 units of the sample mean.

# %% [markdown]
# ##11.  Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process.

# %%
def bayes_theorem(prior, sensitivity, specificity):
    """
    prior: P(Disease) — prior probability of the disease
    sensitivity: P(Positive|Disease) — test sensitivity
    specificity: P(Negative|No Disease) — test specificity
    """
    # Likelihoods
    p_pos_given_disease = sensitivity
    p_pos_given_no_disease = 1 - specificity

    # Marginal probability of positive test
    p_pos = (p_pos_given_disease * prior) + (p_pos_given_no_disease * (1 - prior))

    # Posterior probability
    posterior = (p_pos_given_disease * prior) / p_pos

    # Results
    print(f"Prior (P(Disease))           : {prior:.4f}")
    print(f"Likelihood (P(+|Disease))     : {sensitivity:.2f}")
    print(f"False Positive Rate (P(+|No)) : {p_pos_given_no_disease:.2f}")
    print(f"Marginal P(Positive)          : {p_pos:.4f}")
    print(f"\n🧠 Posterior P(Disease|Positive): {posterior:.4f}")

# Example: Disease affects 1% of population
bayes_theorem(prior=0.01, sensitivity=0.99, specificity=0.95)
# Out:
# Prior (P(Disease))           : 0.0100
# Likelihood (P(+|Disease))     : 0.99
# False Positive Rate (P(+|No)) : 0.05
# Marginal P(Positive)          : 0.0594
#
# 🧠 Posterior P(Disease|Positive): 0.1667

# %% [markdown]
# ##12.  Perform a Chi-square test for independence between two categorical variables in Python.

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

# Step 1: Create contingency table
# Example: Survey of Gender vs Preferred Product
data = pd.DataFrame({
    'Product_A': [30, 20],  # [Male, Female]
    'Product_B': [10, 40]
}, index=['Male', 'Female'])

print("Contingency Table:")
print(data)

# Step 2: Perform Chi-square test
chi2, p, dof, expected = chi2_contingency(data)

# Step 3: Results
print(f"\nChi-square statistic: {chi2:.3f}")
print(f"Degrees of freedom: {dof}")
print(f"P-value: {p:.4f}")

# Step 4: Decision
alpha = 0.05
if p < alpha:
    print("🔴 Reject the Null Hypothesis: Variables are dependent (associated).")
else:
    print("🟢 Fail to Reject the Null Hypothesis: No significant association found.")

# Show expected frequencies
print("\nExpected Frequencies Table:")
print(pd.DataFrame(expected, index=data.index, columns=data.columns))
# Out:
# Contingency Table:
#         Product_A  Product_B
# Male           30         10
# Female         20         40
#
# Chi-square statistic: 15.042
# Degrees of freedom: 1
# P-value: 0.0001
# 🔴 Reject the Null Hypothesis: Variables are dependent (associated).
#
# Expected Frequencies Table:
#         Product_A  Product_B
# Male         20.0       20.0
# Female       30.0       30.0

# %% [markdown]
# ##13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data.

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

# Step 1: Define observed data (contingency table)
# Example: Gender vs Product Preference
observed = pd.DataFrame({
    'Product_A': [30, 20],
    'Product_B': [10, 40]
}, index=['Male', 'Female'])

print("📊 Observed Frequencies:")
display(observed)

# Step 2: Chi-square test (returns expected frequencies too)
chi2_stat, p_value, dof, expected = chi2_contingency(observed)

expected_df = pd.DataFrame(expected, index=observed.index, columns=observed.columns)

# Step 3: Display expected frequencies
print("📈 Expected Frequencies (assuming independence):")
display(expected_df)

# Optional: Comparison summary
comparison = pd.concat(
    [observed.rename(columns=lambda x: x + " (Observed)"),
     expected_df.rename(columns=lambda x: x + " (Expected)")],
    axis=1
)

print("🔍 Side-by-Side Comparison:")
display(comparison)
# Out:
# 📊 Observed Frequencies:
#         Product_A  Product_B
# Male           30         10
# Female         20         40
# 📈 Expected Frequencies (assuming independence):
#         Product_A  Product_B
# Male         20.0       20.0
# Female       30.0       30.0
# 🔍 Side-by-Side Comparison:
#         Product_A (Observed)  Product_B (Observed)  Product_A (Expected)  \
# Male                      30                    10                  20.0
# Female                    20                    40                  30.0
#
#         Product_B (Expected)
# Male                    20.0
# Female                  30.0

# %% [markdown]
# ##14.  Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.

# %%
import numpy as np
from scipy.stats import chisquare

# Step 1: Observed data
observed = np.array([50, 30, 20])  # e.g., frequencies of outcomes A, B, C

# Step 2: Expected proportions (uniform distribution assumed)
expected_proportions = np.array([1/3, 1/3, 1/3])

# Step 3: Scale expected values to match observed total
expected = expected_proportions * np.sum(observed)

# Step 4: Chi-square goodness-of-fit test
chi_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

# Step 5: Results
print("Observed:", observed)
print("Expected:", expected)
print(f"\nChi-Square Statistic: {chi_stat:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("🔴 Reject H₀: Observed data does not fit expected distribution.")
else:
    print("🟢 Fail to Reject H₀: Observed data fits expected distribution.")
# Out:
# Observed: [50 30 20]
# Expected: [33.33333333 33.33333333 33.33333333]
#
# Chi-Square Statistic: 14.0000
# P-value: 0.0009
# 🔴 Reject H₀: Observed data does not fit expected distribution.
